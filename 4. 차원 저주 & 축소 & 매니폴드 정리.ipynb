# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\20.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\21.png")

# %% [markdown]
# log P(y|x; θ)
# = 세타라고 하는 파라미터가 있을때 x가 주어지면 y의 확률의 log
# 여기서 x와 y는 고정이고 θ를 바꿔가면서 MLE을 하는거다
#
# 우리는 이제 매니폴드하고 non-linear deducation를 통해 차원의 저주를 벗어나 낮은차원으로 축소가능하여 효과적인 학습이 가능해졌다.

# %% [markdown]
# ## DataSet

# %% [markdown]
# ## 이 과정 외워!!!!!!!

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\1.png")

# %% [markdown]
# 2. Preprocessing
#
# train_set에 대해 standardization한다 하면 train_set기준으로 뮤와 시그마가 각 feature별로 나오고 그 해당 뮤와 시그마를 validation set에 그대로 적용을 해서 stardarization 을 진행한다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\2.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\3.png")
