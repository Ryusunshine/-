# %%
from IPython.display import Image

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\51.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\52.png")

# %% [markdown]
# Call-back 함수를 써서 코드를 간단하게 만들수있음
#
# 즉 이벤트를 등록할때마다 코드들이 순서에 맞게 실행될거임

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\10.png")

# %% [markdown]
# Engine이라고 하는 class가 있는데 애는 모델에다가 dataloader로부터 미니배치 data를 받아서 모델에 넣어주는 역할이고 for문을 돌려준다
#
# for 문이 돌면서 학습이 되야하는 부분을 process function 이라고 함

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\14.png")

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\11.png")

# %% [markdown]
# train_engine.add_event_handler(
#
# Events.EPOCHS_COMPLETED,
#
# run_validation,
#
# validation_engine,
#
# valid_loader,
# )
#
# add_event_handler라는 함수를 통해서 EPOCH_COMPLETED 이벤트에다가 run_validation함수를 쓸거고 engine, avlidation_engine, valid_loader 이 세개의 파라미터를 넣어줘 라고 event_handelr를 등록한다.
#
# ### 이처럼 편리하게 내가 원하는 코드들을 내가 원하는 시점에 동작시키도록 할수있다.

# %%
Image("C:\\Users\\ryusu\\OneDrive\\바탕 화면\\12.png")

# %% [markdown]
# 작동순서(코드 짜는순서)
# 1. 데이터 읽어오고 (__init__)
# 2. 데이터 길이 함수 짜주고(__len__)
# 3. 미니배치 짜는 함수 만들어주면(__getitem__)
# = DataSet 완성
# 4. 이걸 DataLoader에 넣어주면 train, valid, test loader가 나오게 됨
# 5. .Process_function을 짜고 Train Engine을 선언하고 거기에다가 같이 넣어준다
# 6. 한 epcoh이 끝날때마다 평균 loss를 출력해줌(print Statistics)
# 7. 한 epoch의 학습이 끝나면 한 epoch의 validation을 해야하니깐 Run validation engine을 해준다.
# 8. 그 validation engine은 한 process function을 가지고 있고 DataLoader 로부터 validation set을 받아온다
# 9. Epoch이 끝나면 통계를 찍어준다(Print Statistics)
# 10. 또 Best Loss를 찍어주고 갱신했는지 확인
# 11. Best Loss 저장
# ### 앞으로 이렇게 코드를 짤것이다.
